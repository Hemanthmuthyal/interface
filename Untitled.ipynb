# %%
class Bank_Account:
    def __init__(self,name):
        self.balance=0
        self.name = name
    def deposit(self):
        amount=float(input("Enter amount to be Deposited: "))
        self.balance += amount
        print("\n Amount Deposited:",amount)
    def withdraw(self):
        amount = float(input("Enter amount to be Withdrawn: "))
        if self.balance>=amount:
            self.balance-=amount
            print("\n You Withdrew:", amount)
        else:
            print("\n Insufficient balance ")
    def display(self):
        print("\n Available Balance=",self.balance)
    def transfer(self, amount, name):
        self.balance = self.balance - amount
        name.balance = name.balance + amount 
charan = Bank_Account(charan)
hemanth=Bank_Account(hemanth)
mokhil=Bank_Account(mokhil)
harsha=Bank_Account(harsha)

# %%
a=10000
print("enter account holder name")
x=input()
if x == 'charan':
    name=charan
    print(" welcome charan")
elif x == 'mokhil':
    name=mokhil
    print(" welcome mokhil")
elif x == 'hemanth':
    name=hemanth
    print(" welcome hemanth")
elif x == 'harsha':
    name=harsha
    print(" welcome harsha")
else:
    print("enter vaild account holder name")
    
print('Enter 0 to quit '
'\nEnter 1 to check balance '
'\nEnter 2 to deposit '
'\nEnter 3 to withdraw'
'\nEnter 4 to transfer')
while a != 0:

    a = int(input())
    if a == 1:
        name.display()
    elif a == 2:
        name.deposit()
    elif a == 3:
        name.withdraw()
    elif a==0:
        print("exit")
        break
    elif a==4:
        print('name,amount')
        x=input()
        if x == 'charan':
            ename=charan
        elif x == 'mokhil':
            ename=mokhil
        elif x == 'hemanth':
            ename=hemanth
        elif x == 'harsha':
            ename=harsha
        eamount=int(input())
        name.transfer(eamount,ename)
        print("transfer complete")
    else:
        print("enter a vaild number")
# Out:
# enter account holder name
# charan
#  welcome charan
# Enter 0 to quit
# Enter 1 to check balance
# Enter 2 to deposit
# Enter 3 to withdraw
# Enter 4 to transfer
# 0
# exit
